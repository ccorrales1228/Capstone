# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %matplotlib inline

# Pandas options
pd.set_option('display.max_colwidth', 1000, 'display.max_rows', 200, 'display.max_columns', 200)

# %config Completer.use_jedi = False
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# # Data Loading

# %%
Working_DF = pd.read_csv('clean_accepted.csv', low_memory=True)

# %%
Working_DF.head()
# Out:
#          id  loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# 0  68407277     3600.0       3600.0           3600.0   36 months     13.99
# 1  68355089    24700.0      24700.0          24700.0   36 months     11.99
# 2  68341763    20000.0      20000.0          20000.0   60 months     10.78
# 3  68476807    10400.0      10400.0          10400.0   60 months     22.45
# 4  68426831    11950.0      11950.0          11950.0   36 months     13.44
#
#    installment grade sub_grade             emp_title emp_length  \
# 0       123.03     C        C4               leadman  10+ years
# 1       820.28     C        C1              Engineer  10+ years
# 2       432.66     B        B4          truck driver  10+ years
# 3       289.91     F        F1   Contract Specialist    3 years
# 4       405.18     C        C3  Veterinary Tecnician    4 years
#
#   home_ownership  annual_inc verification_status   issue_d loan_status  \
# 0       MORTGAGE     55000.0        Not Verified  Dec-2015  Fully Paid
# 1       MORTGAGE     65000.0        Not Verified  Dec-2015  Fully Paid
# 2       MORTGAGE     63000.0        Not Verified  Dec-2015  Fully Paid
# 3       MORTGAGE    104433.0     Source Verified  Dec-2015  Fully Paid
# 4           RENT     34000.0     Source Verified  Dec-2015  Fully Paid
#
#   pymnt_plan  \
# 0          n
# 1          n
# 2          n
# 3          n
# 4          n
#
#                                                                  url  \
# 0  https://lendingclub.com/browse/loanDetail.action?loan_id=68407277
# 1  https://lendingclub.com/browse/loanDetail.action?loan_id=68355089
# 2  https://lendingclub.com/browse/loanDetail.action?loan_id=68341763
# 3  https://lendingclub.com/browse/loanDetail.action?loan_id=68476807
# 4  https://lendingclub.com/browse/loanDetail.action?loan_id=68426831
#
#               purpose               title zip_code addr_state    dti  \
# 0  debt_consolidation  Debt consolidation    190xx         PA   5.91
# 1      small_business            Business    577xx         SD  16.06
# 2    home_improvement                 NaN    605xx         IL  10.78
# 3      major_purchase      Major purchase    174xx         PA  25.37
# 4  debt_consolidation  Debt consolidation    300xx         GA  10.20
#
#    delinq_2yrs earliest_cr_line  fico_range_low  fico_range_high  \
# 0          0.0         Aug-2003           675.0            679.0
# 1          1.0         Dec-1999           715.0            719.0
# 2          0.0         Aug-2000           695.0            699.0
# 3          1.0         Jun-1998           695.0            699.0
# 4          0.0         Oct-1987           690.0            694.0
#
#    inq_last_6mths  open_acc  pub_rec  revol_bal  revol_util  total_acc  \
# 0             1.0       7.0      0.0     2765.0        29.7       13.0
# 1             4.0      22.0      0.0    21470.0        19.2       38.0
# 2             0.0       6.0      0.0     7869.0        56.2       18.0
# 3             3.0      12.0      0.0    21929.0        64.5       35.0
# 4             0.0       5.0      0.0     8822.0        68.4        6.0
#
#   initial_list_status  out_prncp  out_prncp_inv   total_pymnt  \
# 0                   w        0.0            0.0   4421.723917
# 1                   w        0.0            0.0  25679.660000
# 2                   w        0.0            0.0  22705.924294
# 3                   w        0.0            0.0  11740.500000
# 4                   w        0.0            0.0  13708.948530
#
#    total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 0          4421.72           3600.0         821.72                 0.0
# 1         25679.66          24700.0         979.66                 0.0
# 2         22705.92          20000.0        2705.92                 0.0
# 3         11740.50          10400.0        1340.50                 0.0
# 4         13708.95          11950.0        1758.95                 0.0
#
#    recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt  \
# 0         0.0                      0.0     Jan-2019           122.67
# 1         0.0                      0.0     Jun-2016           926.35
# 2         0.0                      0.0     Jun-2017         15813.30
# 3         0.0                      0.0     Jul-2016         10128.96
# 4         0.0                      0.0     May-2017          7653.56
#
#   last_credit_pull_d  last_fico_range_high  last_fico_range_low  \
# 0           Mar-2019                 564.0                560.0
# 1           Mar-2019                 699.0                695.0
# 2           Mar-2019                 704.0                700.0
# 3           Mar-2018                 704.0                700.0
# 4           May-2017                 759.0                755.0
#
#    collections_12_mths_ex_med  policy_code application_type  acc_now_delinq  \
# 0                         0.0          1.0       Individual             0.0
# 1                         0.0          1.0       Individual             0.0
# 2                         0.0          1.0        Joint App             0.0
# 3                         0.0          1.0       Individual             0.0
# 4                         0.0          1.0       Individual             0.0
#
#    tot_coll_amt  tot_cur_bal  total_rev_hi_lim  acc_open_past_24mths  \
# 0         722.0     144904.0            9300.0                   4.0
# 1           0.0     204396.0          111800.0                   4.0
# 2           0.0     189699.0           14000.0                   6.0
# 3           0.0     331730.0           34000.0                  10.0
# 4           0.0      12798.0           12900.0                   0.0
#
#    avg_cur_bal  bc_open_to_buy  bc_util  chargeoff_within_12_mths  \
# 0      20701.0          1506.0     37.2                       0.0
# 1       9733.0         57830.0     27.1                       0.0
# 2      31617.0          2737.0     55.9                       0.0
# 3      27644.0          4567.0     77.5                       0.0
# 4       2560.0           844.0     91.0                       0.0
#
#    delinq_amnt  mo_sin_old_il_acct  mo_sin_old_rev_tl_op  \
# 0          0.0               148.0                 128.0
# 1          0.0               113.0                 192.0
# 2          0.0               125.0                 184.0
# 3          0.0               128.0                 210.0
# 4          0.0               338.0                  54.0
#
#    mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  mort_acc  mths_since_recent_bc  \
# 0                    3.0             3.0       1.0                   4.0
# 1                    2.0             2.0       4.0                   2.0
# 2                   14.0            14.0       5.0                 101.0
# 3                    4.0             4.0       6.0                   4.0
# 4                   32.0            32.0       0.0                  36.0
#
#    mths_since_recent_inq  num_accts_ever_120_pd  num_actv_bc_tl  \
# 0                    4.0                    2.0             2.0
# 1                    0.0                    0.0             5.0
# 2                   10.0                    0.0             2.0
# 3                    1.0                    0.0             4.0
# 4                    NaN                    0.0             2.0
#
#    num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 0              4.0          2.0        5.0        3.0            4.0
# 1              5.0         13.0       17.0        6.0           20.0
# 2              3.0          2.0        4.0        6.0            4.0
# 3              6.0          5.0        9.0       10.0            7.0
# 4              3.0          2.0        2.0        2.0            4.0
#
#    num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  \
# 0            9.0                  4.0       7.0               0.0
# 1           27.0                  5.0      22.0               0.0
# 2            7.0                  3.0       6.0               0.0
# 3           19.0                  6.0      12.0               0.0
# 4            4.0                  3.0       5.0               0.0
#
#    num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 0           0.0                 0.0                 3.0            76.9
# 1           0.0                 0.0                 2.0            97.4
# 2           0.0                 0.0                 0.0           100.0
# 3           0.0                 0.0                 4.0            96.6
# 4           0.0                 0.0                 0.0           100.0
#
#    percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 0               0.0                   0.0        0.0         178050.0
# 1               7.7                   0.0        0.0         314017.0
# 2              50.0                   0.0        0.0         218418.0
# 3              60.0                   0.0        0.0         439570.0
# 4             100.0                   0.0        0.0          16900.0
#
#    total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 0             7746.0          2400.0                     13734.0
# 1            39475.0         79300.0                     24667.0
# 2            18696.0          6200.0                     14877.0
# 3            95768.0         20300.0                     88097.0
# 4            12798.0          9400.0                      4000.0
#
#   hardship_flag disbursement_method debt_settlement_flag
# 0             N                Cash                    N
# 1             N                Cash                    N
# 2             N                Cash                    N
# 3             N                Cash                    N
# 4             N                Cash                    N

# %%
Working_DF.shape
# Out:
# (1345310, 93)

# %%
Working_DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1345310 entries, 0 to 1345309
# Data columns (total 93 columns):
#  #   Column                      Non-Null Count    Dtype
# ---  ------                      --------------    -----
#  0   id                          1345310 non-null  int64
#  1   loan_amnt                   1345310 non-null  float64
#  2   funded_amnt                 1345310 non-null  float64
#  3   funded_amnt_inv             1345310 non-null  float64
#  4   term                        1345310 non-null  object
#  5   int_rate                    1345310 non-null  float64
#  6   installment                 1345310 non-null  float64
#  7   grade                       1345310 non-null  object
#  8   sub_grade                   1345310 non-null  object
#  9   emp_title                   1259525 non-null  object
#  10  emp_length                  1266799 non-null  object
#  11  home_ownership              1345310 non-null  object
#  12  annual_inc                  1345310 non-null  float64
#  13  verification_status         1345310 non-null  object
#  14  issue_d                     1345310 non-null  object
#  15  loan_status                 1345310 non-null  object
#  16  pymnt_plan                  1345310 non-null  object
#  17  url                         1345310 non-null  object
#  18  purpose                     1345310 non-null  object
#  19  title                       1328651 non-null  object
#  20  zip_code                    1345309 non-null  object
#  21  addr_state                  1345310 non-null  object
#  22  dti                         1344936 non-null  float64
#  23  delinq_2yrs                 1345310 non-null  float64
#  24  earliest_cr_line            1345310 non-null  object
#  25  fico_range_low              1345310 non-null  float64
#  26  fico_range_high             1345310 non-null  float64
#  27  inq_last_6mths              1345309 non-null  float64
#  28  open_acc                    1345310 non-null  float64
#  29  pub_rec                     1345310 non-null  float64
#  30  revol_bal                   1345310 non-null  float64
#  31  revol_util                  1344453 non-null  float64
#  32  total_acc                   1345310 non-null  float64
#  33  initial_list_status         1345310 non-null  object
#  34  out_prncp                   1345310 non-null  float64
#  35  out_prncp_inv               1345310 non-null  float64
#  36  total_pymnt                 1345310 non-null  float64
#  37  total_pymnt_inv             1345310 non-null  float64
#  38  total_rec_prncp             1345310 non-null  float64
#  39  total_rec_int               1345310 non-null  float64
#  40  total_rec_late_fee          1345310 non-null  float64
#  41  recoveries                  1345310 non-null  float64
#  42  collection_recovery_fee     1345310 non-null  float64
#  43  last_pymnt_d                1342997 non-null  object
#  44  last_pymnt_amnt             1345310 non-null  float64
#  45  last_credit_pull_d          1345255 non-null  object
#  46  last_fico_range_high        1345310 non-null  float64
#  47  last_fico_range_low         1345310 non-null  float64
#  48  collections_12_mths_ex_med  1345254 non-null  float64
#  49  policy_code                 1345310 non-null  float64
#  50  application_type            1345310 non-null  object
#  51  acc_now_delinq              1345310 non-null  float64
#  52  tot_coll_amt                1277783 non-null  float64
#  53  tot_cur_bal                 1277783 non-null  float64
#  54  total_rev_hi_lim            1277783 non-null  float64
#  55  acc_open_past_24mths        1298029 non-null  float64
#  56  avg_cur_bal                 1277761 non-null  float64
#  57  bc_open_to_buy              1284167 non-null  float64
#  58  bc_util                     1283398 non-null  float64
#  59  chargeoff_within_12_mths    1345254 non-null  float64
#  60  delinq_amnt                 1345310 non-null  float64
#  61  mo_sin_old_il_acct          1239735 non-null  float64
#  62  mo_sin_old_rev_tl_op        1277782 non-null  float64
#  63  mo_sin_rcnt_rev_tl_op       1277782 non-null  float64
#  64  mo_sin_rcnt_tl              1277783 non-null  float64
#  65  mort_acc                    1298029 non-null  float64
#  66  mths_since_recent_bc        1285089 non-null  float64
#  67  mths_since_recent_inq       1171239 non-null  float64
#  68  num_accts_ever_120_pd       1277783 non-null  float64
#  69  num_actv_bc_tl              1277783 non-null  float64
#  70  num_actv_rev_tl             1277783 non-null  float64
#  71  num_bc_sats                 1289469 non-null  float64
#  72  num_bc_tl                   1277783 non-null  float64
#  73  num_il_tl                   1277783 non-null  float64
#  74  num_op_rev_tl               1277783 non-null  float64
#  75  num_rev_accts               1277782 non-null  float64
#  76  num_rev_tl_bal_gt_0         1277783 non-null  float64
#  77  num_sats                    1289469 non-null  float64
#  78  num_tl_120dpd_2m            1227909 non-null  float64
#  79  num_tl_30dpd                1277783 non-null  float64
#  80  num_tl_90g_dpd_24m          1277783 non-null  float64
#  81  num_tl_op_past_12m          1277783 non-null  float64
#  82  pct_tl_nvr_dlq              1277629 non-null  float64
#  83  percent_bc_gt_75            1283755 non-null  float64
#  84  pub_rec_bankruptcies        1344613 non-null  float64
#  85  tax_liens                   1345271 non-null  float64
#  86  tot_hi_cred_lim             1277783 non-null  float64
#  87  total_bal_ex_mort           1298029 non-null  float64
#  88  total_bc_limit              1298029 non-null  float64
#  89  total_il_high_credit_limit  1277783 non-null  float64
#  90  hardship_flag               1345310 non-null  object
#  91  disbursement_method         1345310 non-null  object
#  92  debt_settlement_flag        1345310 non-null  object
# dtypes: float64(69), int64(1), object(23)
# memory usage: 954.5+ MB

# %%
pd.crosstab(Working_DF['issue_d'],Working_DF['loan_status'],margins=False) #margins=True to view the total
# Out:
# loan_status  Charged Off  Fully Paid
# issue_d
# Apr-2008              27         128
# Apr-2009              40         250
# Apr-2010              82         745
# Apr-2011             222        1341
# Apr-2012             496        2734
# Apr-2013            1504        7915
# Apr-2014            3320       14852
# Apr-2015            6509       25276
# Apr-2016            6173       17931
# Apr-2017            3118        9985
# Apr-2018            1362        5562
# Aug-2007               7          26
# Aug-2008               6          65
# Aug-2009              40         368
# Aug-2010             148         930
# Aug-2011             271        1663
# Aug-2012             884        4535
# Aug-2013            1941       10733
# Aug-2014            3336       14394
# Aug-2015            6339       25362
# Aug-2016            5822       16436
# Aug-2017            3546       11942
# Aug-2018             315        3254
# Dec-2007              18          67
# Dec-2008              33         190
# Dec-2009              62         536
# Dec-2010             143        1126
#          term grade sub_grade              emp_title emp_length  \
# 0   36 months     A        A4  eligibility Assistant     1 year
# 1   36 months     C        C4      Machine Operator    < 1 year
# 2   36 months     C        C1                    PCA    2 years
# 3   36 months     B        B5                    NaN        NaN
# 4   36 months     C        C1              Engineer   10+ years
#
#   home_ownership verification_status   issue_d loan_status pymnt_plan  \
# 0       MORTGAGE        Not Verified  Aug-2014  Fully Paid          n
# 1            OWN            Verified  Jun-2017  Fully Paid          n
# 2           RENT     Source Verified  Oct-2014  Fully Paid          n
# 3            OWN            Verified  Nov-2015  Fully Paid          n
# 4       MORTGAGE            Verified  May-2016  Fully Paid          n
#
#                                                                   url  \
# 0   https://lendingclub.com/browse/loanDetail.action?loan_id=24765047
# 1  https://lendingclub.com/browse/loanDetail.action?loan_id=110702423
# 2   https://lendingclub.com/browse/loanDetail.action?loan_id=28704495
# 3   https://lendingclub.com/browse/loanDetail.action?loan_id=65482216
# 4   https://lendingclub.com/browse/loanDetail.action?loan_id=78972388
#
#               purpose                    title zip_code addr_state  \
# 0  debt_consolidation       Debt consolidation    953xx         CA
# 1  debt_consolidation       Debt consolidation    923xx         CA
# 2  debt_consolidation       Debt consolidation    015xx         MA
# 3               other                    Other    180xx         PA
# 4         credit_card  Credit card refinancing    791xx         TX
#
#   earliest_cr_line initial_list_status last_pymnt_d last_credit_pull_d  \
# 0         Sep-2000                   w     Mar-2015           Mar-2019
# 1         Oct-2005                   w     Sep-2018           Oct-2018
# 2         Sep-2002                   f     Mar-2017           Mar-2019
# 3         Apr-2000                   f     Nov-2018           Nov-2018
# 4         Oct-1994                   w     Jan-2019           Jan-2019
#
#   application_type hardship_flag disbursement_method debt_settlement_flag
# 0       Individual             N                Cash                    N
# 1        Joint App             N                Cash                    N
# 2       Individual             N                Cash                    N
# 3       Individual             N                Cash                    N
# 4       Individual             N                Cash                    N

# %%
categorical.isnull().any()
# Out:
# term                    False
# grade                   False
# sub_grade               False
# emp_title                True
# emp_length               True
# home_ownership          False
# verification_status     False
# issue_d                 False
# loan_status             False
# pymnt_plan              False
# url                     False
# purpose                 False
# title                    True
# zip_code                 True
# addr_state              False
# earliest_cr_line        False
# initial_list_status     False
# last_pymnt_d             True
# last_credit_pull_d       True
# application_type        False
# hardship_flag           False
# disbursement_method     False
# debt_settlement_flag    False
# dtype: bool

# %%
categorical['grade'].value_counts()
# Out:
# B    196072
# C    190752
# A    117808
# D    100860
# E     46497
# F     16188
# G      4478
# Name: grade, dtype: int64

# %% [markdown]
# ## Second iteration of cutting the data to save on low memory

# %%
data_2 = data.sample(frac=0.5, axis=0, random_state=42).reset_index(drop=True)

# %%
data_2.shape
# Out:
# (336328, 93)

# %%
data_2.head()
# Out:
#           id  loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# 0  103215536    25000.0      25000.0          25000.0   36 months     17.99
# 1   51105809    10000.0      10000.0           9975.0   36 months     11.53
# 2    6728064     6950.0       6950.0           6950.0   36 months     15.88
# 3   59229385    24000.0      24000.0          23950.0   60 months     12.69
# 4   60739473    18000.0      18000.0          18000.0   36 months      7.89
#
#    installment grade sub_grade                         emp_title emp_length  \
# 0       903.69     D        D2                Compliance Manager     1 year
# 1       329.91     B        B5                  customer service    3 years
# 2       243.93     C        C4  Hanson Construction Company, Inc    3 years
# 3       542.28     C        C2                 Senior Consultant    3 years
# 4       563.15     A        A5                   Account Manager    2 years
#
#   home_ownership  annual_inc verification_status   issue_d  loan_status  \
# 
#
#    mths_since_recent_inq  num_accts_ever_120_pd  num_actv_bc_tl  \
# 0                    3.0                    6.0             5.0
# 1                    9.0                    1.0             2.0
# 2                    2.0                    0.0             1.0
# 3                    4.0                    0.0             4.0
# 4                    NaN                    0.0             8.0
#
#    num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 0             13.0          8.0       12.0       10.0           22.0
# 1              6.0          3.0        7.0       14.0            7.0
# 2              2.0          1.0        8.0       10.0            4.0
# 3              4.0          4.0        8.0       10.0            4.0
# 4              9.0          8.0       12.0        4.0           10.0
#
#    num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  \
# 0           42.0                 13.0      25.0               0.0
# 1           13.0                  6.0      20.0               0.0
# 2           31.0                  2.0       6.0               0.0
# 3            9.0                  4.0       9.0               0.0
# 4           14.0                  9.0      12.0               0.0
#
#    num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 0           0.0                 0.0                 5.0            84.9
# 1           0.0                 0.0                 2.0            96.4
# 2           0.0                 0.0                 3.0           100.0
# 3           0.0                 0.0                 3.0           100.0
# 4           0.0                 0.0                 0.0           100.0
#
#    percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 0              25.0                   0.0        0.0         233851.0
# 1              66.7                   0.0        0.0          71528.0
# 2             100.0                   1.0        0.0         233880.0
# 3             100.0                   0.0        0.0         344432.0
# 4              25.0                   0.0        0.0          54475.0
#
#    total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 0            58157.0         28200.0                     32102.0
# 1            62916.0          3500.0                     58728.0
# 2            23540.0         10000.0                     15380.0
# 3            61697.0         25400.0                     54244.0
# 4            21365.0         25600.0                     26875.0
#
#   hardship_flag disbursement_method debt_settlement_flag
# 0             N                Cash                    N
# 1             N                Cash                    N
# 2             N                Cash                    N
# 3             N                Cash                    N
# 4             N                Cash                    N

# %%
data_2['grade'].value_counts()
# Out:
# B    97900
# C    95284
# A    58777
# D    50646
# E    23266
# F     8198
# G     2257
# Name: grade, dtype: int64

# %%
#data_2['emp_title'].value_counts()

# %%
data_2['loan_status'].value_counts()
# Out:
# Fully Paid     269049
# Charged Off     67279
# Name: loan_status, dtype: int64

# %%
data_2['home_ownership'].value_counts()
# Out:
# MORTGAGE    166609
# RENT        133482
# OWN          36108
# ANY             78
# OTHER           39
# NONE            12
# Name: home_ownership, dtype: int64

# %%
data_2.to_csv("clean_accepted_2.csv", index=False)

# %%
data_2.groupby(["home_ownership", "loan_status"]).size().unstack().plot(kind='bar', stacked=False, figsize=(8,8)).set_title('Demographic of Target to Home Ownership')
# Out:
# Text(0.5, 1.0, 'Demographic of Target to Home Ownership')

# %% [markdown]
# ## Checking for missing values

# %%
missing_row = data_2.isnull().sum(axis=1)

# %%
sum(missing_row > 10)
# Out:
# 17120

# %%
## Dropping any row with missing values
columns = data_2.columns

# %%
columns
# Out:
# Index(['id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
#        'installment', 'grade', 'sub_grade', 'emp_title', 'emp_length',
#        'home_ownership', 'annual_inc', 'verification_status', 'issue_d',
#        'loan_status', 'pymnt_plan', 'url', 'purpose', 'title', 'zip_code',
#        'addr_state', 'dti', 'delinq_2yrs', 'earliest_cr_line',
#        'fico_range_low', 'fico_range_high', 'inq_last_6mths', 'open_acc',
#        'pub_rec', 'revol_bal', 'revol_util', 'total_acc',
#        'initial_list_status', 'out_prncp', 'out_prncp_inv', 'total_pymnt',
#        'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_d', 'last_pymnt_amnt', 'last_credit_pull_d',
#        'last_fico_range_high', 'last_fico_range_low',
#        'collections_12_mths_ex_med', 'policy_code', 'application_type',
#        'acc_now_delinq', 'tot_coll_amt', 'tot_cur_bal', 'total_rev_hi_lim',
#        'acc_open_past_24mths', 'avg_cur_bal', 'bc_open_to_buy', 'bc_util',
#        'chargeoff_within_12_mths', 'delinq_amnt', 'mo_sin_old_il_acct',
#        'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl',
#        'mort_acc', 'mths_since_recent_bc', 'mths_since_recent_inq',
#        'num_accts_ever_120_pd', 'num_actv_bc_tl', 'num_actv_rev_tl',
#        'num_bc_sats', 'num_bc_tl', 'num_il_tl', 'num_op_rev_tl',
#        'num_rev_accts', 'num_rev_tl_bal_gt_0', 'num_sats', 'num_tl_120dpd_2m',
#        'num_tl_30dpd', 'num_tl_90g_dpd_24m', 'num_tl_op_past_12m',
#        'pct_tl_nvr_dlq', 'percent_bc_gt_75', 'pub_rec_bankruptcies',
#        'tax_liens', 'tot_hi_cred_lim', 'total_bal_ex_mort', 'total_bc_limit',
#        'total_il_high_credit_limit', 'hardship_flag', 'disbursement_method',
#        'debt_settlement_flag'],
#       dtype='object')

# %%
drop_missing = pd.DataFrame(data_2, columns=columns)

# %%
drop_missing.shape
# Out:
# (336328, 93)

# %%
data_2 = drop_missing.dropna()

# %%
data_2.shape
# Out:
# (246269, 93)

# %%
data_2.describe()
# Out:
#                  id      loan_amnt    funded_amnt  funded_amnt_inv  \
# count  2.462690e+05  246269.000000  246269.000000    246269.000000
# mean   5.855681e+07   14843.904734   14843.898237     14838.030051
# std    3.733918e+07    8792.352950    8792.360815      8789.388802
# min    5.612100e+04    1000.000000    1000.000000       750.000000
# 25%    2.609760e+07    8000.000000    8000.000000      8000.000000
# 50%    5.916073e+07   12800.000000   12800.000000     12800.000000
# 75%    8.571207e+07   20000.000000   20000.000000     20000.000000
# max    1.456237e+08   40000.000000   40000.000000     40000.000000
000000
#
#        num_op_rev_tl  num_rev_accts  num_rev_tl_bal_gt_0       num_sats  \
# count  246269.000000  246269.000000        246269.000000  246269.000000
# mean        8.507214      14.903520             5.688463      12.131628
# std         4.606310       8.144323             3.224342       5.544633
# min         1.000000       1.000000             0.000000       1.000000
# 25%         5.000000       9.000000             3.000000       8.000000
# 50%         8.000000      13.000000             5.000000      11.000000
# 75%        11.000000      19.000000             7.000000      15.000000
# max        72.000000     127.000000            43.000000      79.000000
#
#        num_tl_120dpd_2m   num_tl_30dpd  num_tl_90g_dpd_24m  \
# count     246269.000000  246269.000000       246269.000000
# mean           0.000873       0.003728            0.084919
# std            0.031913       0.065190            0.492505
# min            0.000000       0.000000            0.000000
# 25%            0.000000       0.000000            0.000000
# 50%            0.000000       0.000000            0.000000
# 75%            0.000000       0.000000            0.000000
# max            6.000000       4.000000           26.000000
#
#        num_tl_op_past_12m  pct_tl_nvr_dlq  percent_bc_gt_75  \
# count       246269.000000   246269.000000     246269.000000
# mean             2.304943       94.277055         44.466408
# std              1.850813        8.516490         35.753841
# min              0.000000        7.100000          0.000000
# 25%              1.000000       91.700000         10.000000
# 50%              2.000000       97.700000         40.000000
# 75%              3.000000      100.000000         75.000000
# max             30.000000      100.000000        100.000000
#
#        pub_rec_bankruptcies      tax_liens  tot_hi_cred_lim  \
# count         246269.000000  246269.000000     2.462690e+05
# mean               0.137350       0.056243     1.838690e+05
# std                0.386033       0.450941     1.776100e+05
# min                0.000000       0.000000     5.000000e+02
# 25%                0.000000       0.000000     5.538800e+04
# 50%                0.000000       0.000000     1.257820e+05
# 75%                0.000000       0.000000     2.645800e+05
# max               12.000000      85.000000     9.999999e+06
#
#        total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit
# count       2.462690e+05   246269.000000                2.462690e+05
# mean        5.322830e+04    21976.366672                4.584585e+04
# std         4.958218e+04    21636.163690                4.459098e+04
# min         0.000000e+00      100.000000                0.000000e+00
# 25%         2.370800e+04     8000.000000                1.810100e+04
# 50%         4.045300e+04    15400.000000                3.500000e+04
# 75%         6.624800e+04    28500.000000                6.043100e+04
# max         2.688920e+06   760000.000000                2.101913e+06

# %%
##Saving into CSV
data_2.to_csv("clean_accepted_2.csv", index=False)

# %%
missing_percent = data_2.isna().mean().sort_values(ascending = False).round(4) * 100

# %%
missing_percent
# Out:
# id                            0.0
# chargeoff_within_12_mths      0.0
# num_accts_ever_120_pd         0.0
# mths_since_recent_inq         0.0
# mths_since_recent_bc          0.0
# mort_acc                      0.0
# mo_sin_rcnt_tl                0.0
# mo_sin_rcnt_rev_tl_op         0.0
# mo_sin_old_rev_tl_op          0.0
# mo_sin_old_il_acct            0.0
# delinq_amnt                   0.0
# bc_util                       0.0
# last_fico_range_low           0.0
# bc_open_to_buy                0.0
# avg_cur_bal                   0.0
# acc_open_past_24mths          0.0
# total_rev_hi_lim              0.0
# tot_cur_bal                   0.0
# tot_coll_amt                  0.0
# acc_now_delinq                0.0
# application_type              0.0
# policy_code                   0.0
# num_actv_bc_tl                0.0
# num_actv_rev_tl               0.0
# num_bc_sats                   0.0
# num_bc_tl                     0.0
# disbursement_method           0.0
# hardship_flag                 0.0
# total_il_high_credit_limit    0.0
# total_bc_limit                0.0
# total_bal_ex_mort             0.0
# tot_hi_cred_lim               0.0
# tax_liens                     0.0
# pub_rec_bankruptcies          0.0
# percent_bc_gt_75              0.0
# pct_tl_nvr_dlq                0.0
# num_tl_op_past_12m            0.0
# num_tl_90g_dpd_24m            0.0
# num_tl_30dpd                  0.0
# num_tl_120dpd_2m              0.0
# num_sats                      0.0
# num_rev_tl_bal_gt_0           0.0
# num_rev_accts                 0.0
# num_op_rev_tl                 0.0
# num_il_tl                     0.0
# collections_12_mths_ex_med    0.0
# last_fico_range_high          0.0
# loan_amnt                     0.0
# annual_inc                    0.0
# addr_state                    0.0
# zip_code                      0.0
# title                         0.0
# purpose                       0.0
# url                           0.0
# pymnt_plan                    0.0
# loan_status                   0.0
# issue_d                       0.0
# verification_status           0.0
# home_ownership                0.0
# last_credit_pull_d            0.0
# emp_length                    0.0
# emp_title                     0.0
# sub_grade                     0.0
# grade                         0.0
# installment                   0.0
# int_rate                      0.0
# term                          0.0
# funded_amnt_inv               0.0
# funded_amnt                   0.0
# dti                           0.0
# delinq_2yrs                   0.0
# earliest_cr_line              0.0
# fico_range_low                0.0
# last_pymnt_amnt               0.0
# last_pymnt_d                  0.0
# collection_recovery_fee       0.0
# recoveries                    0.0
# total_rec_late_fee            0.0
# total_rec_int                 0.0
# total_rec_prncp               0.0
# total_pymnt_inv               0.0
# total_pymnt                   0.0
# out_prncp_inv                 0.0
# out_prncp                     0.0
# initial_list_status           0.0
# total_acc                     0.0
# revol_util                    0.0
# revol_bal                     0.0
# pub_rec                       0.0
# open_acc                      0.0
# inq_last_6mths                0.0
# fico_range_high               0.0
# debt_settlement_flag          0.0
# dtype: float64

# %% [markdown]
# # Data Cleansing

# %%
import seaborn as sns 
target = data_2['loan_status'].value_counts()
sns.barplot(target.index, target.values).set_title('Demographic of Target')
#plt.savefig('Target_bar')
# Out:
# /Users/B_A_S_i_C/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Demographic of Target')

# %%
data_2['loan_status'].value_counts()
# Out:
# Fully Paid     197386
# Charged Off     48883
# Name: loan_status, dtype: int64

# %%
categorical = data_2.select_dtypes('object')
categorical.describe()
# Out:
#               term   grade sub_grade emp_title emp_length home_ownership  \
# count       246269  246269    246269    246269     246269         246269
# unique           2       7        35     94194         11              6
# top      36 months       C        C1   Teacher  10+ years       MORTGAGE
# freq        183412   71260     15641      4419      86809         126956
#
#        verification_status   issue_d loan_status pymnt_plan  \
# count               246269    246269      246269     246269
# unique                   3        77           2          1
# top        Source Verified  Mar-2016  Fully Paid          n
# freq                102862      8711      197386     246269
#
#                                                                       url  \
# count                                                              246269
# unique                                                             246269
# top     https://lendingclub.com/browse/loanDetail.action?loan_id=70010903
# freq                                                                    1
#
#                    purpose               title zip_code addr_state  \
# count               246269              246269   246269     246269
# unique                  13               10039      898         51
# top     debt_consolidation  Debt consolidation    750xx         CA
# freq                145597              129904     2914      34771
#
#        earliest_cr_line initial_list_status last_pymnt_d last_credit_pull_d  \
# count            246269              246269       246269             246269
# unique              662                   2           78                 78
# top            Aug-2001                   w     Aug-2018           Mar-2019
# freq               1901              150365         7372              88403
#
#        application_type hardship_flag disbursement_method debt_settlement_flag
# count            246269        246269              246269               246269
# unique                2             1                   2                    2
# top          Individual             N                Cash                    N
# freq             241649        246269              244995               239873

# %%
sorted(categorical)
# Out:
# ['addr_state',
#  'application_type',
#  'debt_settlement_flag',
#  'disbursement_method',
#  'earliest_cr_line',
#  'emp_length',
#  'emp_title',
#  'grade',
#  'hardship_flag',
#  'home_ownership',
#  'initial_list_status',
#  'issue_d',
#  'last_credit_pull_d',
#  'last_pymnt_d',
#  'loan_status',
#  'purpose',
#  'pymnt_plan',
#  'sub_grade',
#  'term',
#  'title',
#  'url',
#  'verification_status',
#  'zip_code']

# %%
categorical.shape
# Out:
# (246269, 23)

# %%
continous = data_2.select_dtypes('number').head()
continous.describe()
# Out:
#                  id     loan_amnt   funded_amnt  funded_amnt_inv   int_rate  \
# count  5.000000e+00      5.000000      5.000000         5.000000   5.000000
# mean   4.620292e+07  16190.000000  16190.000000     16165.000000  16.616000
# std    3.956117e+07   8119.759849   8119.759849      8114.369969   5.334658
# min    6.728064e+06   6950.000000   6950.000000      6950.000000  11.530000
# 25%    1.073581e+07  10000.000000  10000.000000      9975.000000  12.690000
# 50%    5.110581e+07  15000.000000  15000.000000     14950.000000  15.880000
# 75%    5.922938e+07  24000.000000  24000.000000     23950.000000  17.990000
# max    1.032155e+08  25000.000000  25000.000000     25000.000000  24.990000
#
#        installment     annual_inc       dti  delinq_2yrs  fico_range_low  \
# count     5.000000       5.000000   5.00000     5.000000         5.00000
# mean    492.000000   63862.000000  22.67000     0.600000       673.00000
# std     256.180065   23251.617578   4.73933     0.894427        14.40486
# min     243.930000   41810.000000  17.25000     0.000000       660.00000
# 25%     329.910000   45000.000000  19.41000     0.000000       665.00000
# 50%     440.190000   65000.000000  22.22000     0.000000       665.00000
# 75%     542.280000   67500.000000  25.24000     1.000000       680.00000
# max     903.690000  100000.000000  29.23000     2.000000       695.00000
#
#        fico_range_high  inq_last_6mths  open_acc   pub_rec     revol_bal  \
# count          5.00000         5.00000   5.00000  5.000000      5.000000
# mean         677.00000         0.80000  15.20000  0.200000  18752.600000
# std           14.40486         1.30384   7.79102  0.447214  15144.788024
# min          664.00000         0.00000   6.00000  0.000000   7459.000000
# 25%          669.00000         0.00000   9.00000  0.000000   9269.000000
# 50%          669.00000         0.00000  16.00000  0.000000  10723.000000
# 75%          684.00000         1.00000  20.00000  0.000000  22654.000000
# max          699.00000         3.00000  25.00000  1.000000  43658.000000
#
#        revol_util  total_acc  out_prncp  out_prncp_inv   total_pymnt  \
# count    5.000000   5.000000        5.0            5.0      5.000000
# mean    57.420000  38.200000        0.0            0.0  16445.817053
# std     22.605464  12.969194        0.0            0.0   7699.171551
# min     25.300000  22.000000        0.0            0.0   8781.472301
# 25%     56.300000  28.000000        0.0            0.0  11581.198232
# 50%     58.000000  43.000000        0.0            0.0  15828.970000
# 75%     58.300000  44.000000        0.0            0.0  17191.390013
# max     89.200000  54.000000        0.0            0.0  28846.054719
#
#        total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# count         5.000000         5.000000       5.000000            5.000000
# mean      16416.548000     12954.526000    3028.268000            3.300000
# std        7678.187917      6856.430936    1612.424071            7.379024
# min        8781.470000      6950.000000    1564.700000            0.000000
# 25%       11552.250000      8822.630000    1831.470000            0.000000
# 50%       15828.970000     10000.000000    2191.390000            0.000000
# 75%       17134.090000     15000.000000    4707.730000            0.000000
# max       28785.960000     24000.000000    4846.050000           16.500000
#
#         recoveries  collection_recovery_fee  last_pymnt_amnt  \
# count     5.000000                 5.000000         5.000000
# mean    459.722000                82.749960      6044.134000
# std    1027.969643               185.034536      6989.431903
# min       0.000000                 0.000000       243.920000
# 25%       0.000000                 0.000000       903.690000
# 50%       0.000000                 0.000000      4643.000000
# 75%       0.000000                 0.000000      6866.250000
# max    2298.610000               413.749800     17563.810000
#
#        last_fico_range_high  last_fico_range_low  collections_12_mths_ex_med  \
#
#        num_tl_120dpd_2m  num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  \
# count               5.0           5.0            5.000000                 5.0
# mean                0.0           0.0            0.200000                 4.0
# std                 0.0           0.0            0.447214                 2.0
# min                 0.0           0.0            0.000000                 2.0
# 25%                 0.0           0.0            0.000000                 3.0
# 50%                 0.0           0.0            0.000000                 3.0
# 75%                 0.0           0.0            0.000000                 5.0
# max                 0.0           0.0            1.000000                 7.0
#
#        pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# count        5.000000          5.000000              5.000000        5.0
# mean        93.460000         60.840000              0.200000        0.0
# std          7.468467         40.995768              0.447214        0.0
# min         84.900000         12.500000              0.000000        0.0
# 25%         86.000000         25.000000              0.000000        0.0
# 50%         96.400000         66.700000              0.000000        0.0
# 75%        100.000000        100.000000              0.000000        0.0
# max        100.000000        100.000000              1.000000        0.0
#
#        tot_hi_cred_lim  total_bal_ex_mort  total_bc_limit  \
# count         5.000000           5.000000        5.000000
# mean     236655.200000       50644.200000    19280.000000
# std      103511.540176       16414.765204    11753.169785
# min       71528.000000       23540.000000     3500.000000
# 25%      233851.000000       46911.000000    10000.000000
# 50%      233880.000000       58157.000000    25400.000000
# 75%      299585.000000       61697.000000    28200.000000
# max      344432.000000       62916.000000    29300.000000
#
#        total_il_high_credit_limit
# count                      5.0000
# mean                   42709.8000
# std                    18418.1722
# min                    15380.0000
# 25%                    32102.0000
# 50%                    53095.0000
# 75%                    54244.0000
# max                    58728.0000

# %%
sorted(continous.columns)
# Out:
# ['acc_now_delinq',
#  'acc_open_past_24mths',
#  'annual_inc',
#  'avg_cur_bal',
#  'bc_open_to_buy',
#  'bc_util',
#  'chargeoff_within_12_mths',
#  'collection_recovery_fee',
#  'collections_12_mths_ex_med',
#  'delinq_2yrs',
#  'delinq_amnt',
#  'dti',
#  'fico_range_high',
#  'fico_range_low',
#  'funded_amnt',
#  'funded_amnt_inv',
#  'id',
#  'inq_last_6mths',
#  'installment',
#  'int_rate',
#  'last_fico_range_high',
#  'last_fico_range_low',
#  'last_pymnt_amnt',
#  'loan_amnt',
#  'mo_sin_old_il_acct',
#  'mo_sin_old_rev_tl_op',
#  'mo_sin_rcnt_rev_tl_op',
#  'mo_sin_rcnt_tl',
#  'mort_acc',
#  'mths_since_recent_bc',
#  'mths_since_recent_inq',
#  'num_accts_ever_120_pd',
#  'num_actv_bc_tl',
#  'num_actv_rev_tl',
#  'num_bc_sats',
#  'num_bc_tl',
#  'num_il_tl',
#  'num_op_rev_tl',
#  'num_rev_accts',
#  'num_rev_tl_bal_gt_0',
#  'num_sats',
#  'num_tl_120dpd_2m',
#  'num_tl_30dpd',
#  'num_tl_90g_dpd_24m',
#  'num_tl_op_past_12m',
#  'open_acc',
#  'out_prncp',
#  'out_prncp_inv',
#  'pct_tl_nvr_dlq',
#  'percent_bc_gt_75',
#  'policy_code',
#  'pub_rec',
#  'pub_rec_bankruptcies',
#  'recoveries',
#  'revol_bal',
#  'revol_util',
#  'tax_liens',
#  'tot_coll_amt',
#  'tot_cur_bal',
#  'tot_hi_cred_lim',
#  'total_acc',
#  'total_bal_ex_mort',
#  'total_bc_limit',
#  'total_il_high_credit_limit',
#  'total_pymnt',
#  'total_pymnt_inv',
#  'total_rec_int',
#  'total_rec_late_fee',
#  'total_rec_prncp',
#  'total_rev_hi_lim']

# %%
continous.shape
# Out:
# (5, 70)

# %% [markdown]
# Creating a keep_list of which features that are important to focus on based on domain knownledge.
#
# Also these features are key regarding the application process.

# %%
keep_features = ['addr_state', 'annual_inc', 'application_type', 'bc_util', 'dti', 'earliest_cr_line', 'emp_length',
                    'emp_title', 'fico_range_high', 'fico_range_low', 'grade', 'home_ownership', 'id', 
                     'initial_list_status', 'inq_last_6mths', 'installment', 'int_rate', 'issue_d','loan_amnt',
                        'loan_status', 'mort_acc', 'open_acc', 'pub_rec', 'pub_rec_bankruptcies', 'purpose',
                         'pymnt_plan', 'recoveries', 'revol_bal', 'revol_util', 'sub_grade', 'tax_liens', 'term',
                         'title', 'tot_cur_bal', 'total_acc', 'verification_status', 'zip_code']

# %%
drop_features = [columns for columns in data_2.columns if columns not in keep_features]

# %%
sorted(drop_features)
# Out:
# ['acc_now_delinq',
#  'acc_open_past_24mths',
#  'avg_cur_bal',
#  'bc_open_to_buy',
#  'chargeoff_within_12_mths',
#  'collection_recovery_fee',
#  'collections_12_mths_ex_med',
#  'debt_settlement_flag',
#  'delinq_2yrs',
#  'delinq_amnt',
#  'disbursement_method',
#  'funded_amnt',
#  'funded_amnt_inv',
#  'hardship_flag',
#  'last_credit_pull_d',
#  'last_fico_range_high',
#  'last_fico_range_low',
#  'last_pymnt_amnt',
#  'last_pymnt_d',
#  'mo_sin_old_il_acct',
#  'mo_sin_old_rev_tl_op',
#  'mo_sin_rcnt_rev_tl_op',
#  'mo_sin_rcnt_tl',
#  'mths_since_recent_bc',
#  'mths_since_recent_inq',
#  'num_accts_ever_120_pd',
#  'num_actv_bc_tl',
#  'num_actv_rev_tl',
#  'num_bc_sats',
#  'num_bc_tl',
#  'num_il_tl',
#  'num_op_rev_tl',
#  'num_rev_accts',
#  'num_rev_tl_bal_gt_0',
#  'num_sats',
#  'num_tl_120dpd_2m',
#  'num_tl_30dpd',
#  'num_tl_90g_dpd_24m',
#  'num_tl_op_past_12m',
#  'out_prncp',
#  'out_prncp_inv',
#  'pct_tl_nvr_dlq',
#  'percent_bc_gt_75',
#  'policy_code',
#  'tot_coll_amt',
#  'tot_hi_cred_lim',
#  'total_bal_ex_mort',
#  'total_bc_limit',
#  'total_il_high_credit_limit',
#  'total_pymnt',
#  'total_pymnt_inv',
#  'total_rec_int',
#  'total_rec_late_fee',
#  'total_rec_prncp',
#  'total_rev_hi_lim',
#  'url']

# %%
len(drop_features)
# Out:
# 56

# %%
data_2.drop(labels=drop_features, axis=1, inplace=True)
# Out:
# /Users/B_A_S_i_C/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
data_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 246269 entries, 0 to 336327
# Data columns (total 37 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    246269 non-null  int64
#  1   loan_amnt             246269 non-null  float64
#  2   term                  246269 non-null  object
#  3   int_rate              246269 non-null  float64
#  4   installment           246269 non-null  float64
#  5   grade                 246269 non-null  object
#  6   sub_grade             246269 non-null  object
#  7   emp_title             246269 non-null  object
#  8   emp_length            246269 non-null  object
#  9   home_ownership        246269 non-null  object
#  10  annual_inc            246269 non-null  float64
#  11  verification_status   246269 non-null  object
#  12  issue_d               246269 non-null  object
#  13  loan_status           246269 non-null  object
#  14  pymnt_plan            246269 non-null  object
#  15  purpose               246269 non-null  object
#  16  title                 246269 non-null  object
#  17  zip_code              246269 non-null  object
#  18  addr_state            246269 non-null  object
#  19  dti                   246269 non-null  float64
#  20  earliest_cr_line      246269 non-null  object
#  21  fico_range_low        246269 non-null  float64
#  22  fico_range_high       246269 non-null  float64
#  23  inq_last_6mths        246269 non-null  float64
#  24  open_acc              246269 non-null  float64
#  25  pub_rec               246269 non-null  float64
#  26  revol_bal             246269 non-null  float64
#  27  revol_util            246269 non-null  float64
#  28  total_acc             246269 non-null  float64
#  29  initial_list_status   246269 non-null  object
#  30  recoveries            246269 non-null  float64
#  31  application_type      246269 non-null  object
#  32  tot_cur_bal           246269 non-null  float64
#  33  bc_util               246269 non-null  float64
#  34  mort_acc              246269 non-null  float64
#  35  pub_rec_bankruptcies  246269 non-null  float64
#  36  tax_liens             246269 non-null  float64
# dtypes: float64(19), int64(1), object(17)
# memory usage: 71.4+ MB

# %%
file_name = 'final_ds.xlsx'

# %%
# saving the excel 
data_2.to_excel(file_name) 
print('DataFrame is written to Excel File successfully.')
# Out:
# DataFrame is written to Excel File successfully.

# %% [markdown]
# # Lite EDA

# %%
data_2['loan_status'].value_counts()
# Out:
# Fully Paid     197386
# Charged Off     48883
# Name: loan_status, dtype: int64

# %%
continous = data_2.select_dtypes('number').head()
continous.describe()
# Out:
#                  id     loan_amnt   int_rate  installment     annual_inc  \
# count  5.000000e+00      5.000000   5.000000     5.000000       5.000000
# mean   4.620292e+07  16190.000000  16.616000   492.000000   63862.000000
# std    3.956117e+07   8119.759849   5.334658   256.180065   23251.617578
# min    6.728064e+06   6950.000000  11.530000   243.930000   41810.000000
# 25%    1.073581e+07  10000.000000  12.690000   329.910000   45000.000000
# 50%    5.110581e+07  15000.000000  15.880000   440.190000   65000.000000
# 75%    5.922938e+07  24000.000000  17.990000   542.280000   67500.000000
# max    1.032155e+08  25000.000000  24.990000   903.690000  100000.000000
#
#             dti  fico_range_low  fico_range_high  inq_last_6mths  open_acc  \
# count   5.00000         5.00000          5.00000         5.00000   5.00000
# mean   22.67000       673.00000        677.00000         0.80000  15.20000
# std     4.73933        14.40486         14.40486         1.30384   7.79102
# min    17.25000       660.00000        664.00000         0.00000   6.00000
# 25%    19.41000       665.00000        669.00000         0.00000   9.00000
# 50%    22.22000       665.00000        669.00000         0.00000  16.00000
# 75%    25.24000       680.00000        684.00000         1.00000  20.00000
# max    29.23000       695.00000        699.00000         3.00000  25.00000
#
#         pub_rec     revol_bal  revol_util  total_acc   recoveries  \
# count  5.000000      5.000000    5.000000   5.000000     5.000000
# mean   0.200000  18752.600000   57.420000  38.200000   459.722000
# std    0.447214  15144.788024   22.605464  12.969194  1027.969643
# min    0.000000   7459.000000   25.300000  22.000000     0.000000
# 25%    0.000000   9269.000000   56.300000  28.000000     0.000000
# 50%    0.000000  10723.000000   58.000000  43.000000     0.000000
# 75%    0.000000  22654.000000   58.300000  44.000000     0.000000
# max    1.000000  43658.000000   89.200000  54.000000  2298.610000
#
#          tot_cur_bal    bc_util  mort_acc  pub_rec_bankruptcies  tax_liens
# count       5.000000   5.000000  5.000000              5.000000        5.0
# mean   193589.800000  65.040000  1.600000              0.200000        0.0
# std     84796.686505  30.908704  0.894427              0.447214        0.0
# min     62916.000000  27.200000  0.000000              0.000000        0.0
# 25%    173292.000000  39.400000  2.000000              0.000000        0.0
# 50%    197096.000000  71.000000  2.000000              0.000000        0.0
# 75%    253377.000000  89.200000  2.000000              0.000000        0.0
# max    281268.000000  98.400000  2.000000              1.000000        0.0

# %%
sorted(continous.columns)
# Out:
# ['annual_inc',
#  'bc_util',
#  'dti',
#  'fico_range_high',
#  'fico_range_low',
#  'id',
#  'inq_last_6mths',
#  'installment',
#  'int_rate',
#  'loan_amnt',
#  'mort_acc',
#  'open_acc',
#  'pub_rec',
#  'pub_rec_bankruptcies',
#  'recoveries',
#  'revol_bal',
#  'revol_util',
#  'tax_liens',
#  'tot_cur_bal',
#  'total_acc']

# %%
categorical = data_2.select_dtypes('object')
categorical.describe()
# Out:
#               term   grade sub_grade emp_title emp_length home_ownership  \
# count       246269  246269    246269    246269     246269         246269
# unique           2       7        35     94194         11              6
# top      36 months       C        C1   Teacher  10+ years       MORTGAGE
# freq        183412   71260     15641      4419      86809         126956
#
#        verification_status   issue_d loan_status pymnt_plan  \
# count               246269    246269      246269     246269
# unique                   3        77           2          1
# top        Source Verified  Mar-2016  Fully Paid          n
# freq                102862      8711      197386     246269
#
#                    purpose               title zip_code addr_state  \
# count               246269              246269   246269     246269
# unique                  13               10039      898         51
# top     debt_consolidation  Debt consolidation    750xx         CA
# freq                145597              129904     2914      34771
#
#        earliest_cr_line initial_list_status application_type
# count            246269              246269           246269
# unique              662                   2                2
# top            Aug-2001                   w       Individual
# freq               1901              150365           241649

# %%
sorted(categorical.columns)
# Out:
# ['addr_state',
#  'application_type',
#  'earliest_cr_line',
#  'emp_length',
#  'emp_title',
#  'grade',
#  'home_ownership',
#  'initial_list_status',
#  'issue_d',
#  'loan_status',
#  'purpose',
#  'pymnt_plan',
#  'sub_grade',
#  'term',
#  'title',
#  'verification_status',
#  'zip_code']

# %% [markdown]
# sns.pairplot(data_2[['loan_status', 'annual_inc', 'bc_util', 'dti','fico_range_high','fico_range_low','inq_last_6mths','installment',
#                      'int_rate', 'loan_amnt','mort_acc','open_acc', 'pub_rec', 'pub_rec_bankruptcies','recoveries',
#                      'revol_bal','revol_util','tax_liens','tot_cur_bal','total_acc']], hue="loan_status")

# %%
# Creating a function for visualizations for Bi-variant analysis

def plot_var(col_name, full_name, continuous):
    """
    This function is meant to help show features and the relationship to the target (loan_status).
    - col_name, variable name within the df
    - full_name, name of the variable/title 
    - continuous, True if continuous; False if categorical
    """
    f, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, figsize=(14,14))
    
    
    # Plot without loan status
    if continuous:
        sns.distplot(data_2.loc[data_2[col_name].notnull(), col_name], kde=False, ax=ax1)
        #plt.xticks(rotation=45, horizontalalignment='right')
    else:
        sns.countplot(data_2[col_name], order=sorted(data_2[col_name].unique()), ax=ax1)
        ax1.set_xlabel(full_name)
        ax1.set_ylabel('Count')
        ax1.set_title(full_name)
        #ax1.set.xticks(rotation=45, horizontalalignment='right')
    
    

    # Plot with loan status
    if continuous:
        sns.boxplot(x=col_name, y='loan_status', data=data_2, ax=ax2)
        ax2.set_ylabel('')
        ax2.set_title(full_name + ' by Loan Status')
        plt.xticks(rotation=45, horizontalalignment='right')
    else:
        charge_off_rates = data_2.groupby(col_name)['loan_status'].value_counts(normalize=True).loc[:,'Charged Off']
        sns.barplot(x=charge_off_rates.index, y=charge_off_rates.values, ax=ax2)
        ax2.set_ylabel('Fraction of Loans Charged-off')
        ax2.set_title('Charge-off Rate by ' + full_name)
        plt.xticks(rotation=45, horizontalalignment='right')
        ax2.set_xlabel(full_name)
    
    plt.show()

# %%
## function created for PDF of continous variables and target

def pdf_cont(col_name, full_name):

    fig = plt.subplots(figsize=(6, 6))
    data_2.groupby(['loan_status'])[col_name].plot(kind='kde', legend=True)
    plt.title(full_name);

# Because the classes are imbalanced, I think 'kde' is more preferred than 'hist' here.

# %%
pdf_cont('loan_amnt', 'Distribution of Loan to Target')

# %% [markdown]
# ## Loan Amount

# %%
plot_var('loan_amnt', 'Loan Amount', continuous=True)
# Out:
# /Users/B_A_S_i_C/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Grade and Sub-grade

# %%
plot_var('grade', 'Grade', continuous=False)
# Out:
# /Users/B_A_S_i_C/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plot_var('sub_grade', 'Sub-grade', continuous=False)
# Out:
# /Users/B_A_S_i_C/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## FICO Score

# %%
plot_var('fico_range_high', 'FICO (High Range)', continuous=True)
# Out:
# /Users/B_A_S_i_C/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
pdf_cont('fico_range_high', 'Distribution of FICO Score (High Range) to Target')

# %%
data_2['fico_range_high'].value_counts()
# Out:
# 664.0    23034
# 674.0    22080
# 669.0    21739
# 679.0    19422
# 684.0    19254
# 689.0    16935
# 694.0    16389
# 699.0    14575
# 704.0    13457
# 709.0    11960
# 714.0    10375
# 719.0     9229
# 724.0     7825
# 729.0     6131
# 734.0     5417
# 739.0     4278
# 744.0     3623
# 749.0     2944
# 754.0     2691
# 759.0     2302
# 764.0     1817
# 769.0     1757
# 774.0     1411
# 779.0     1371
# 784.0     1190
# 789.0      959
# 794.0      916
# 799.0      685
# 804.0      633
# 809.0      551
# 814.0      392
# 819.0      312
# 824.0      217
# 829.0      181
# 834.0      109
# 839.0       51
# 844.0       32
# 850.0       25
# Name: fico_range_high, dtype: int64

# %%
plot_var('fico_range_low', 'FICO (Low Range)', continuous=True)
# Out:
# /Users/B_A_S_i_C/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
pdf_cont('fico_range_low', 'Distribution of FICO Score (Low Range) to Target')

# %%
data_2['fico_range_low'].value_counts()
# Out:
# 660.0    23034
# 670.0    22080
# 665.0    21739
# 675.0    19422
# 680.0    19254
# 685.0    16935
# 690.0    16389
# 695.0    14575
# 700.0    13457
# 705.0    11960
# 710.0    10375
# 715.0     9229
# 720.0     7825
# 725.0     6131
# 730.0     5417
# 735.0     4278
# 740.0     3623
# 745.0     2944
# 750.0     2691
# 755.0     2302
# 760.0     1817
# 765.0     1757
# 770.0     1411
# 775.0     1371
# 780.0     1190
# 785.0      959
# 790.0      916
# 795.0      685
# 800.0      633
# 805.0      551
# 810.0      392
# 815.0      312
# 820.0      217
# 825.0      181
# 830.0      109
# 835.0       51
# 840.0       32
# 845.0       25
# Name: fico_range_low, dtype: int64

# %% [markdown]
# ## Checking the Issue date of the loan

# %%
pd.crosstab(data_2['issue_d'],data_2['loan_status'],margins=False) #margins=True to view the total
# Out:
# loan_status  Charged Off  Fully Paid
# issue_d
# Apr-2013             288        1628
# Apr-2014             642        2921
# Apr-2015            1277        4898
# Apr-2016            1101        3217
# Apr-2017             546        1989
# Apr-2018             233        1130
# Aug-2012              23         147
# Aug-2013             391        2133
# Aug-2014             692        2953
# Aug-2015            1244        4779
# Aug-2016             990        3126
# Aug-2017             654        2348
# Aug-2018              34         634
# Dec-2012             178        1029
# Dec-2013             452        2484
# Dec-2014             355        1525
# Dec-2015            1580        5823
# Dec-2016             860        2867
# Dec-2017             355        1529
# Dec-2018               0         231
# Feb-2013             252        1297
# Feb-2014             495        2420
# Feb-2015             838        3410
# Feb-2016            1189        4873
# Feb-2017             519        2121
# Feb-2018             199        1038
# Jan-2013             195        1171
# Jan-2014             467        2597
# Jan-2015            1354        5231
# Jan-2016             967        4009
# Jan-2017             681        2478
# Jan-2018             306        1366
# Jul-2013             378        1945
# Jul-2014            1071        4418
# Jul-2015            1617        6247
# Jul-2016            1059        3126
# Jul-2017             636        2251
# Jul-2018              84         765
# Jun-2013             361        1831
# Jun-2014             650        2610
# Jun-2015            1083        3933
# Jun-2016             934        3046
# Jun-2017             669        2284
# Jun-2018             120         787
# Mar-2013             239        1433
# Mar-2014             502        2616
# Mar-2015             934        3570
# Mar-2016            1790        6921
# Mar-2017             737        2545
# Mar-2018             234        1135
# May-2013             335        1743
# May-2014             646        2995
# May-2015            1188        4459
# May-2016             809        2477
# May-2017             709        2460
# May-2018             198        1070
# Nov-2012             218        1062
# Nov-2013             447        2548
# Nov-2014             907        3716
# Nov-2015            1275        4953
# Nov-2016             827        2651
# Nov-2017             418        1821
# Nov-2018               3         314
# Oct-2012             201        1017
# Oct-2013             420        2421
# Oct-2014            1466        5653
# Oct-2015            1556        6359
# Oct-2016             848        2895
# Oct-2017             478        1830
# Oct-2018               4         396
# Sep-2012             188        1029
# Sep-2013             401        2236
# Sep-2014             406        1654
# Sep-2015            1033        3852
# Sep-2016             810        2493
# Sep-2017             623        1970
# Sep-2018              14         447

# %% [markdown]
# ###### Only shows a six year spread might consider going back to working_df as it shows a 10 year spread

# %% [markdown]
# ## Installments

# %%
plot_var('installment', 'Installments', continuous=True)
# Out:
# /Users/B_A_S_i_C/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Purpose

# %%
plot_var('purpose', 'Purpose', continuous=False)
# Out:
# /Users/B_A_S_i_C/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Lite ML with PyCaret, no feature engineering

# %% [markdown]
# fig, axs = plt.subplots(1, 3, figsize=(15, 5))
# sns.countplot(x='international plan', hue='churn', data=df, ax=axs[0])
# axs[0].set_title('international plan')
# sns.countplot(x='voice mail plan', hue='churn', data=df, ax=axs[1])
# axs[1].set_title('oice mail plan')
# sns.countplot(x='area code', hue='churn', data=df, ax=axs[2])
# axs[2].set_title('area code')
# #plt.savefig('categorical')

# %%
#df = pd.read_csv('clean_accepted_2.csv', low_memory=True)
